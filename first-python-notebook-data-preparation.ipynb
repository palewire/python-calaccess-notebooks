# %% [markdown]
# # "First Python Notebook" data preparation
#
# By Ben Welsh
#
# Preparing a sample dataset to be used in a forthcoming class entitled "First Python Notebook: Scripting your way to the story." The class is scheduled to be taught as part of [an October 2016 "watchdog workshop" organized by Investigative Reporters and Editors](http://ire.org/events-and-training/event/2819/2841/) at San Diego State University's journalism school.
#
# The class will focus on analyzing the contributors to one of this November's statewide ballot measures. Because the raw data published at [californiacivicdata.org](http://www.californiacivicdata.org) is still difficult for beginners to navigate, a simplified version for students will be prepared below.

# %% [markdown]
# ### Import Python tools

# %%
import os
import requests
from datetime import datetime
from clint.textui import progress

# %%
import pandas
pandas.set_option('display.float_format', lambda x: '%.2f' % x)
pandas.set_option('display.max_columns', None)

# %% [markdown]
# ### Download raw data
#
# Pull down raw CAL-ACCESS files published by the California Civic Data Coalition's API.

# %%
def download_csv(name):
    """
    Accepts the name of a calaccess.download CSV and returns its path.
    """
    path = os.path.join(os.getcwd(), '{}.csv'.format(name))
    if not os.path.exists(path):
        url = "http://calaccess.download/latest/{}.csv".format(name)
        r = requests.get(url, stream=True)
        with open(path, 'w') as f:
            total_length = int(r.headers.get('content-length'))
            for chunk in progress.bar(r.iter_content(chunk_size=1024), expected_size=(total_length/1024) + 1): 
                if chunk:
                    f.write(chunk)
                    f.flush()
    return path

# %% [markdown]
# Itemized receipts reported by campaigns

# %%
rcpt_path = download_csv("rcpt_cd")

# %%
ff_path = download_csv("filer_filings_cd")

# %% [markdown]
# ### Hack down RCPT_CD table outside of Python
#
# The raw `RCPT_CD` table is nearly 2 gigabytes in size and too large to load into this Python notebook. Outside of this script, I split it into slices of 1,000,000 rows using the Linux command line.
#
# ```bash
# $ split -l 1000000 rcpt_cd.csv rcpt_cd_part
# ```
#
# I then cleaned up the file names a little and added the header row to all files using ``vim``.

# %% [markdown]
# ### Import and trim the RCPT_CD table
#
# The source file is believed to expand in chronological order as new filings are made with the state. Since we are only interested in studying contributions to a 2016 ballot, only the three latest slices are imported and trimmed.

# %%
def rcpt_part_to_dataframe(part_name):
    """
    Import a slide of the RCPT_CD table prepared for this notebook.
    """
    file_name = "rcpt_cd_parta{}.csv".format(part_name)
    path = os.path.join(os.getcwd(), file_name)
    return pandas.read_csv(path, sep=',', dtype="unicode")

# %%
itemized_receipts_df_h = rcpt_part_to_dataframe("h")

# %%
itemized_receipts_df_i = rcpt_part_to_dataframe("i")

# %%
itemized_receipts_df_j = rcpt_part_to_dataframe("j")

# %% [markdown]
# Concatenate them together into one DataFrame.

# %%
recent_itemized_receipts = pandas.concat([
    itemized_receipts_df_h,
    itemized_receipts_df_i,
    itemized_receipts_df_j
])

# %% [markdown]
# Remove amended filings

# %%
def remove_amended_filings(df):
    """
    Accepts a dataframe with FILING_ID and AMEND_ID files.
    
    Returns only the highest amendment for each unique filing id.
    """
    max_amendments = df.groupby('FILING_ID')['AMEND_ID'].agg("max").reset_index()
    merged_df = pandas.merge(df, max_amendments, how='inner', on=['FILING_ID', 'AMEND_ID'])
    print "Removed {} amendments".format(len(df)-len(merged_df))
    print "DataFrame now contains {} rows".format(len(merged_df))
    return merged_df

# %%
real_recent_itemized_receipts = remove_amended_filings(recent_itemized_receipts)
# Out:
# Removed 659557 amendments
# DataFrame now contains 1960681 rows

# %% [markdown]
# Filter the table down to monetary contributions reported via Schedule A.

# %%
real_sked_a = real_recent_itemized_receipts[
    real_recent_itemized_receipts['FORM_TYPE'] == 'A'
]

# %% [markdown]
# Reduce the number of the headers down to the ones we want to keep

# %%
trimmed_itemized = real_sked_a[[
    'FILING_ID',
    'AMEND_ID',
    'CTRIB_NAMF',
    'CTRIB_NAML',
    'CTRIB_CITY',
    'CTRIB_ST',
    'CTRIB_ZIP4',
    'CTRIB_EMP',
    'CTRIB_OCC',
    'RCPT_DATE',
    'AMOUNT',
]]

# %% [markdown]
# Rename the ugly ones

# %%
clean_itemized = trimmed_itemized.rename(
    index=str,
    columns={
        "CTRIB_NAMF": "FIRST_NAME",
        "CTRIB_NAML": "LAST_NAME",
        "CTRIB_CITY": "CITY",
        "CTRIB_ST": "STATE",
        "CTRIB_ZIP4": "ZIPCODE",
        "CTRIB_EMP": "EMPLOYER",
        "CTRIB_OCC": "OCCUPATION",
        "RCPT_DATE": "DATE"
    }
)

# %% [markdown]
# ### Import and trim the FILER_FILINGS_CD table
#
# Download and read in the table with links between the ``RCPT_CD`` table's ``FILING_ID`` field and the ``FILER_ID`` field that identifies which committee reported the receipt.

# %%
filer_filings_df = pandas.read_csv(ff_path, sep=',', index_col=False, dtype='unicode')

# %% [markdown]
# Since this table does not indicate if the filing is an amendment, let's just reduce it to the distinct connections between filers and filings.

# %%
filer_to_filing = filer_filings_df[['FILER_ID', 'FILING_ID']].drop_duplicates()

# %% [markdown]
# ### Import the shortlist of Prop. 64 committees we want to study

# %% [markdown]
# California's Proposition 64 asks voters if the growth and sale marijuana should be legalized in the state. As of September 20, [California's Secretary of State reports](http://www.sos.ca.gov/campaign-lobbying/cal-access-resources/measure-contributions/marijuana-legalization-initiative-statute/) that 16 million has been raised to campaign in support the measure, and 2 million to oppose it.

# %% [markdown]
# Here are the committees the state lists as supporting the measure.

# %%
supporting_committees = pandas.DataFrame([
    {"COMMITTEE_ID":"1343793","COMMITTEE_NAME":"Californians for Responsible Marijuana Reform, Sponsored by Drug Policy Action, Yes on Prop. 64"},
    {"COMMITTEE_ID":"1376077","COMMITTEE_NAME":"Californians for Sensible Reform, Sponsored by Ghost Management Group, LLC dba Weedmaps"},
    {"COMMITTEE_ID":"1385506","COMMITTEE_NAME":"Drug Policy Action - Non Profit 501c4, Yes on Prop. 64"},
    {"COMMITTEE_ID":"1385745","COMMITTEE_NAME":"Fund for Policy Reform (Nonprofit 501(C)(4))"},
    {"COMMITTEE_ID":"1371855","COMMITTEE_NAME":"Marijuana Policy Project of California"},
    {"COMMITTEE_ID":"1382525","COMMITTEE_NAME":"New Approach PAC (MPO)"},
    {"COMMITTEE_ID":"1386560","COMMITTEE_NAME":"The Adult Use Campaign for Proposition 64"},
    {"COMMITTEE_ID":"1381808","COMMITTEE_NAME":"Yes on 64, Californians to Control, Regulate and Tax Adult Use of Marijuana While Protecting Children, Sponsored by Business, Physicians, Environmental and Social-Justice Advocate Organizations"}
])
supporting_committees['COMMITTEE_POSITION'] = 'SUPPORT'

# %% [markdown]
# Here are the committees the state lists as opposing the measure.

# %%
opposing_committees = pandas.DataFrame([
    {"COMMITTEE_ID":"1382568","COMMITTEE_NAME":"No on Prop. 64, Sponsored by California Public Safety Institute"},
    {"COMMITTEE_ID":"1387789","COMMITTEE_NAME":"Sam Action, Inc., a Committee Against Proposition 64 with Help from Citizens (NonProfit 501(C)(4))"}
])
opposing_committees['COMMITTEE_POSITION'] = 'OPPOSE'

# %%
prop_64_committees = pandas.concat([supporting_committees, opposing_committees])

# %% [markdown]
# ### Join Prop. 64 committees to the contributions they've received

# %%
prop_64_filings = filer_to_filing.merge(
    prop_64_committees,
    how="inner",
    left_on='FILER_ID',
    right_on="COMMITTEE_ID"
)

# %%
prop_64_itemized = prop_64_filings.merge(
    clean_itemized,
    how="inner",
    left_on="FILING_ID",
    right_on="FILING_ID"
)

# %%
print len(prop_64_itemized)
# Out:
# 318

# %% [markdown]
# ### Export the data to a CSV file

# %%
prop_64_itemized.drop('FILER_ID', axis=1, inplace=True)

# %%
prop_64_itemized.to_csv("./prop_64_contributions.csv", index=False)

# %%
prop_64_itemized
# Out:
#     FILING_ID COMMITTEE_ID                                     COMMITTEE_NAME  \
# 0     1680042      1343793  Californians for Responsible Marijuana Reform,...
# 1     1937009      1343793  Californians for Responsible Marijuana Reform,...
# 2     2038717      1343793  Californians for Responsible Marijuana Reform,...
# 3     2038717      1343793  Californians for Responsible Marijuana Reform,...
# 4     2038717      1343793  Californians for Responsible Marijuana Reform,...
# 5     2063970      1343793  Californians for Responsible Marijuana Reform,...
# 6     2063970      1343793  Californians for Responsible Marijuana Reform,...
# 7     2063970      1343793  Californians for Responsible Marijuana Reform,...
# 8     2063970      1343793  Californians for Responsible Marijuana Reform,...
# 9     2063970      1343793  Californians for Responsible Marijuana Reform,...
# 10    2063970      1343793  Californians for Responsible Marijuana Reform,...
# 11    2063970      1343793  Californians for Responsible Marijuana Reform,...
# 12    2063970      1343793  Californians for Responsible Marijuana Reform,...
# 13    2063970      1343793  Californians for Responsible Marijuana Reform,...
# 14    2063970      1343793  Californians for Responsible Marijuana Reform,...
# 15    2063970      1343793  Californians for Responsible Marijuana Reform,...
# 16    2063970      1343793  Californians for Responsible Marijuana Reform,...
# 17    2063970      1343793  Californians for Responsible Marijuana Reform,...
# 18    2063970      1343793  Californians for Responsible Marijuana Reform,...
# 19    2063970      1343793  Californians for Responsible Marijuana Reform,...
# 20    2063970      1343793  Californians for Responsible Marijuana Reform,...
# 21    2063970      1343793  Californians for Responsible Marijuana Reform,...
# 22    2063970      1343793  Californians for Responsible Marijuana Reform,...
# 23    2063970      1343793  Californians for Responsible Marijuana Reform,...
# 24    2063970      1343793  Californians for Responsible Marijuana Reform,...
# 25    2063970      1343793  Californians for Responsible Marijuana Reform,...
# 26    2063970      1343793  Californians for Responsible Marijuana Reform,...
# 27    2063970      1343793  Californians for Responsible Marijuana Reform,...
# 28    2063970      1343793  Californians for Responsible Marijuana Reform,...
# 29    2063970      1343793  Californians for Responsible Marijuana Reform,...
# ..        ...          ...                                                ...
# 288   2064127      1382568  No on Prop. 64, Sponsored by California Public...
# 289   2064127      1382568  No on Prop. 64, Sponsored by California Public...
# 290   2064127      1382568  No on Prop. 64, Sponsored by California Public...
# 291   2064127      1382568  No on Prop. 64, Sponsored by California Public...
# 292   2064127      1382568  No on Prop. 64, Sponsored by California Public...
# 293   2064127      1382568  No on Prop. 64, Sponsored by California Public...
# 294   2064127      1382568  No on Prop. 64, Sponsored by California Public...
# 295   2064127      1382568  No on Prop. 64, Sponsored by California Public...
# 296   2064127      1382568  No on Prop. 64, Sponsored by California Public...
# 297   2064127      1382568  No on Prop. 64, Sponsored by California Public...
# 298   2064127      1382568  No on Prop. 64, Sponsored by California Public...
# 299   2064127      1382568  No on Prop. 64, Sponsored by California Public...
# 300   2064127      1382568  No on Prop. 64, Sponsored by California Public...
# 301   2064127      1382568  No on Prop. 64, Sponsored by California Public...
# 302   2064127      1382568  No on Prop. 64, Sponsored by California Public...
# 303   2064127      1382568  No on Prop. 64, Sponsored by California Public...
# 304   2038497      1382525                             New Approach PAC (MPO)
# 305   2038497      1382525                             New Approach PAC (MPO)
# 306   2038497      1382525                             New Approach PAC (MPO)
# 307   2063087      1382525                             New Approach PAC (MPO)
# 308   2064069      1385506  Drug Policy Action - Non Profit 501c4, Yes on ...
# 309   2064069      1385506  Drug Policy Action - Non Profit 501c4, Yes on ...
# 310   2064069      1385506  Drug Policy Action - Non Profit 501c4, Yes on ...
# 311   2064069      1385506  Drug Policy Action - Non Profit 501c4, Yes on ...
# 312   2057298      1385745       Fund for Policy Reform (Nonprofit 501(C)(4))
# 313   2057298      1385745       Fund for Policy Reform (Nonprofit 501(C)(4))
# 314   2064155      1387789  Sam Action, Inc., a Committee Against Proposit...
# 315   2064155      1387789  Sam Action, Inc., a Committee Against Proposit...
# 316   2064155      1387789  Sam Action, Inc., a Committee Against Proposit...
# 317   2064155      1387789  Sam Action, Inc., a Committee Against Proposit...
#
#     COMMITTEE_POSITION AMEND_ID FIRST_NAME  \
# 0              SUPPORT        0        NaN
# 1              SUPPORT        0       Luke
# 2              SUPPORT        1      Susan
# 3              SUPPORT        1     Philip
# 4              SUPPORT        1      Kevin
# 5              SUPPORT        0    Jessica
# 6              SUPPORT        0    Patrick
# 7              SUPPORT        0    Maureen
# 8              SUPPORT        0       Evan
# 9              SUPPORT        0      Bruce
# 10             SUPPORT        0      Bruce
# 11             SUPPORT        0        NaN
# 12             SUPPORT        0        Bob
# 13             SUPPORT        0        NaN
# 14             SUPPORT        0      Ellen
# 15             SUPPORT        0     Thomas
# 16             SUPPORT        0      David
# 17             SUPPORT        0    Genifer
# 18             SUPPORT        0      Ethan
# 19             SUPPORT        0      Ethan
# 20             SUPPORT        0  Elizabeth
# 21             SUPPORT        0        Ken
# 22             SUPPORT        0      Katie
# 23             SUPPORT        0       Adam
# 24             SUPPORT        0      Milan
# 25             SUPPORT        0      Emily
# 26             SUPPORT        0      Nancy
# 27             SUPPORT        0        Jon
# 28             SUPPORT        0    Jessica
# 29             SUPPORT        0    William
# ..                 ...      ...        ...
# 288             OPPOSE        0        NaN
# 289             OPPOSE        0      David
# 290             OPPOSE        0       Eric
# 291             OPPOSE        0     RONALD
# 292             OPPOSE        0        NaN
# 293             OPPOSE        0    CECILIA
# 294             OPPOSE        0        NaN
# 295             OPPOSE        0        NaN
# 296             OPPOSE        0     Robert
# 297             OPPOSE        0        Dan
# 298             OPPOSE        0        Sam
# 299             OPPOSE        0        NaN
# 300             OPPOSE        0        NaN
# 301             OPPOSE        0        NaN
# 302             OPPOSE        0      JAMES
# 303             OPPOSE        0        NaN
# 304            SUPPORT        0       Sean
# 305            SUPPORT        0     Daniel
# 306            SUPPORT        0     Daniel
# 307            SUPPORT        0      Henry
# 308            SUPPORT        0        NaN
# 309            SUPPORT        0        NaN
# 310            SUPPORT        0        NaN
# 311            SUPPORT        0        NaN
# 312            SUPPORT        0        NaN
# 313            SUPPORT        0        NaN
# 314             OPPOSE        1      Julie
# 315             OPPOSE        1      Julie
# 316             OPPOSE        1      Julie
# 317             OPPOSE        1      Julie
#
#                                              LAST_NAME               CITY  \
# 0    Drug Policy Action Committee to Tax and Regula...         Sacramento
# 1                                          Sinquefield  Pacific Palisades
# 2                                             Podolsky            Modesto
# 3                                                Davis            Salinas
# 4                                              Herbert      San Francisco
# 5                                            McElfresh    Rancho Santa Fe
# 6                                            McManamon           Westlake
# 7                                             McNamara             Denver
# 8                                                 Metz              Miami
# 9                                             Milligan           Bellevue
# 10                                            Milligan           Bellevue
# 11                                     MJ Freeway, LLC             Denver
# 12                                              Morgan            Chicago
# 13                               Mountain High Suckers             Denver
# 14                                                 Moy           Torrance
# 15                                             Mundell          Bridgeton
# 16                                               Muret            Seattle
# 17                                              Murray         Scottsdale
# 18                                           Nadelmann           New York
# 19                                           Nadelmann           New York
# 20                                             Nichols             Edmond
# 21                                               Novak          Palo Alto
# 22                                             O'Block            Boulder
# 23                                               Orens             Denver
# 24                                               Patel         Scottsdale
# 25                                              Paxhia      San Francisco
# 26                                           Pemberton         Sebastopol
# 27                                               Perri      San Francisco
# 28                                              Peters            Oakland
# 29                                            Pletcher      Downers Grove
# ..                                                 ...                ...
# 288                     Laguna Beach Police Employees'       Laguna Beach
# 289                                          McCartney          Hollister
# 290                                              Nunez       Los Alamitos
# 291                                            JOHNSON           Murrieta
# 292   ASSOC. FOR LOS ANGELES DEPUTY SHERIFFS STATE PIC      MONTEREY PARK
# 293                                             GALVIN             CLOVIS
# 294                                   SAM ACTION, INC.           NEW YORK
# 295                           Tejada Threat Management             Orinda
# 296                                              Handy   HUNTINGTON Beach
# 297                                            DeSmidt            Belmont
# 298                                            Spiegel             Folsom
# 299                                               CNOA      Santa Clarita
# 300                                   SAM ACTION, INC.           NEW YORK
# 301                      CALIF. STATE SHERIFFS' ASSOC.         SACRAMENTO
# 302                                              DAVIS          SUNNYVALE
# 303        MULDOON FOR NEWPORT BEACH CITY COUNCIL 2016          SANTA ANA
# 304                                             Parker          Palo Alto
# 305                                              Lewis       Coral Gables
# 306                                              Lewis       Coral Gables
# 307                                      van Ameringen           New York
# 308                                 Drug Policy Action            Oakland
# 309                                 Drug Policy Action            Oakland
# 310      Fund for Policy Reform (nonprofit 501 (c)(4))           New York
# 311      Fund for Policy Reform (nonprofit 501 (c)(4))           New York
# 312                             Fund for Policy Reform         Wilmington
# 313                             Fund for Policy Reform         Wilmington
# 314                                            Schauer               Oaks
# 315                                            Schauer               Oaks
# 316                                            Schauer               Oaks
# 317                                            Schauer               Oaks
#
#     STATE ZIPCODE                                EMPLOYER  \
# 0      CA   95815                                     NaN
# 1      CA   90272                        Luke Sinquefield
# 2      CA   95350             Ontario Base Hospital Group
# 3      CA   93901     Monterey County Office of Education
# 4      CA   94110             Platina Systems Corporation
# 5      CA   92019                       Jessica McElfresh
# 6      OH   44145       Cannasure Insurance Services, LLC
# 7      CO   80211                       Cannabis Trainers
# 8      FL   33179                           ECA Solutions
# 9      WA   98005             Mobius Beverage Corporation
# 10     WA   98005             Mobius Beverage Corporation
# 11     CO   80202                                     NaN
# 12     IL   60015                      Much Shelist, P.C.
# 13     CO   80223                                     NaN
# 14     CA   90504                               Ellen Moy
# 15     MO   63044                                     n/a
# 16     WA   98104                       Viridian Staffing
# 17     AZ   85260                  Carbon Blue Consulting
# 18     NY   10023                    Drug Policy Alliance
# 19     NY   10023                    Drug Policy Alliance
# 20     OK   73034                                 Rosebud
# 21     CA   94303                               Ken Novak
# 22     CO   80301                             Surna, Inc.
# 23     CO   80202                  Marijuana Policy Group
# 24     AZ   85260                             Pathogen DX
# 25     CA   94117               Poseidon Asset Management
# 26     CA   95473                         Nancy Pemberton
# 27     CA   94115                              Change.org
# 28     CA   94601                              Moxie Meds
# 29     IL   60516                              MCAH, LTD.
# ..    ...     ...                                     ...
# 288    CA   92652                                     NaN
# 289    CA   95023                     City of Watsonville
# 290    CA   90720  City of Los Alamitos Police Department
# 291    CA   92563                                 Retired
# 292    CA   91755                                     NaN
# 293    CA   93619                                     NaN
# 294    NY   10014                                     NaN
# 295    CA   94563                                     NaN
# 296    CA   92649                City of Huntington Beach
# 297    CA   94002                     Belmont Police Dept
# 298    CA   95630                                 Retired
# 299    CA   91355                                     NaN
# 300    NY   10014                                     NaN
# 301    CA   95814                                     NaN
# 302    CA   94086                       CITY OF SUNNYVALE
# 303    CA   92705                                     NaN
# 304    CA   94301                  Sean Parker Foundation
# 305    FL   33146                                     NaN
# 306    FL   33146                                     NaN
# 307    NY   10011                                     NaN
# 308    CA   94612                                     NaN
# 309    CA   94612                                     NaN
# 310    NY   10019                                     NaN
# 311    NY   10019                                     NaN
# 312    DE   19809                                     NaN
# 313    DE   19809                                     NaN
# 314    PA   19456                                     NaN
# 315    PA   19456                                     NaN
# 316    PA   19456                                     NaN
# 317    PA   19456                                     NaN
#
#                       OCCUPATION                   DATE    AMOUNT
# 0                            NaN   1/3/2012 12:00:00 AM  10975.51
# 1                        Realtor  7/25/2014 12:00:00 AM     15000
# 2                      Physician  3/21/2016 12:00:00 AM       100
# 3                      Education  3/21/2016 12:00:00 AM       250
# 4    Principal Software Engineer  3/31/2016 12:00:00 AM       100
# 5                       Attorney   6/7/2016 12:00:00 AM       100
# 6        Chief Executive Officer  6/17/2016 12:00:00 AM      2500
# 7                       Training  6/27/2016 12:00:00 AM       100
# 8           Business Development  6/27/2016 12:00:00 AM       100
# 9                        Founder  6/17/2016 12:00:00 AM        25
# 10                       Founder  6/19/2016 12:00:00 AM        75
# 11                           NaN  6/13/2016 12:00:00 AM      2500
# 12                      Attorney  6/20/2016 12:00:00 AM       100
# 13                           NaN  6/24/2016 12:00:00 AM       200
# 14                      Attorney  6/24/2016 12:00:00 AM       100
# 15                       Retired  6/14/2016 12:00:00 AM       100
# 16                    Co-Founder  6/16/2016 12:00:00 AM       100
# 17                         Owner  6/27/2016 12:00:00 AM       100
# 18            Executive Director   5/5/2016 12:00:00 AM       110
# 19            Executive Director   6/7/2016 12:00:00 AM        75
# 20                      Attorney  6/24/2016 12:00:00 AM       100
# 21                    Consultant   6/7/2016 12:00:00 AM       100
# 22                     Marketing  6/17/2016 12:00:00 AM       200
# 23                    Consultant  6/20/2016 12:00:00 AM       100
# 24       Chief Executive Officer  6/24/2016 12:00:00 AM       100
# 25                   Investments  6/17/2016 12:00:00 AM      2500
# 26                       Analyst  6/29/2016 12:00:00 AM       100
# 27            Campaigns Director   6/9/2016 12:00:00 AM       100
# 28                     President  6/16/2016 12:00:00 AM       200
# 29                     President  6/27/2016 12:00:00 AM       100
# ..                           ...                    ...       ...
# 288                          NaN   6/9/2016 12:00:00 AM       100
# 289                 Deputy Chief  6/10/2016 12:00:00 AM       100
# 290              Chief of Police  6/10/2016 12:00:00 AM       100
# 291              Chief of Police  6/12/2016 12:00:00 AM       100
# 292                          NaN  6/13/2016 12:00:00 AM      5000
# 293                 NOT EMPLOYED  6/13/2016 12:00:00 AM       150
# 294                          NaN  6/13/2016 12:00:00 AM     36000
# 295                          NaN  6/14/2016 12:00:00 AM       100
# 296                 Police Chief  6/24/2016 12:00:00 AM       100
# 297              Chief of Police  6/27/2016 12:00:00 AM       150
# 298       Chief of Police - Ret.  6/28/2016 12:00:00 AM       200
# 299                          NaN  6/29/2016 12:00:00 AM      5000
# 300                          NaN  6/29/2016 12:00:00 AM     18150
# 301                          NaN  6/30/2016 12:00:00 AM     10000
# 302               COUNCIL MEMBER  6/30/2016 12:00:00 AM       100
# 303                          NaN  6/30/2016 12:00:00 AM       500
# 304                     Chairman  1/28/2016 12:00:00 AM    250000
# 305                      Retired  3/31/2016 12:00:00 AM    500000
# 306                      Retired   1/6/2016 12:00:00 AM    250000
# 307                      Retired  6/30/2016 12:00:00 AM   1000000
# 308                          NaN   1/5/2016 12:00:00 AM    250000
# 309                          NaN   2/2/2016 12:00:00 AM    250000
# 310                          NaN   5/3/2016 12:00:00 AM    550000
# 311                          NaN  5/26/2016 12:00:00 AM    420000
# 312                          NaN   5/3/2016 12:00:00 AM    550000
# 313                          NaN  5/26/2016 12:00:00 AM    420000
# 314                      RETIRED  4/13/2016 12:00:00 AM     14000
# 315                      RETIRED  5/20/2016 12:00:00 AM     35000
# 316                      RETIRED   6/8/2016 12:00:00 AM    120000
# 317                      RETIRED  6/13/2016 12:00:00 AM     45000
#
# [318 rows x 14 columns]

# %% [markdown]
# ### Upload the data to the World Wide Web
#
# I then uploaded that CSV export to Google Sheets, where it is published online [here](https://docs.google.com/spreadsheets/d/1Zsxlq01Wqu9D1qLLesjA7aGwclYTGeNsPY4Ax_jwtYI/pubhtml?gid=0&single=true).
#
# Caveats to keep in mind:
#
# - The file contains only contributions reported through June 30, 2016, when the most recent quarterly F460 filings were made. It does not include "late" expenditures reported via F497 form in the weeks leading up to the election.
# - It is also only monetary contributions reported via the Form 460's Schedule A. It does not include non-monetary contributions, nor does it include transfers and other cash infusions reported via Schedule I. That can add up to a significant amount of missing money. For instance, hundreds of thousands of dollars from George Soros were passed into the Drug Policy Action PAC from a previous ballot measure campaign in [this filing's](http://cal-access.sos.ca.gov/PDFGen/pdfgen.prg?filingid=1740525&amendid=0) Schedule I.
# - Some campaigns here, such as Drug Policy Action, have passed on their contributions to other ballot measure committees. The result is that some real dollars are reflected twice. First, when they are reported as receiptsby the initial committee. Then again when they are reported as receipts by the second committee after they first has passed it along.
# - As is always the case, these receipts are only those of "large donors" that campaigns are required to report when they surpass 200 dollars in gifts. Donors who have given less than that amount do not appear, and the summary sheets reported by the campaigns remain the authoritative source of their total fundraising.
