# %% [markdown]
# # Contributors to California Civic Data Coalition repositories
#
# By Ben Welsh
#
# This analysis is drawn from the open-source list of contributors compiled by GitHub. It was last harvested on Dec. 18, 2016, [using a Python script that interacts with GitHub's API](https://github.com/california-civic-data-coalition/django-calaccess-raw-data/blob/master/example/network-analysis/contributors.csv).

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load in the data

# %%
table = pd.read_csv("./contributors.csv")

# %%
table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183 entries, 0 to 182
# Data columns (total 9 columns):
# repo             183 non-null object
# login            183 non-null object
# name             141 non-null object
# email            93 non-null object
# company          93 non-null object
# location         118 non-null object
# bio              27 non-null object
# avatar_url       183 non-null object
# contributions    183 non-null int64
# dtypes: int64(1), object(8)
# memory usage: 12.9+ KB

# %%
table = table.replace(np.nan, "")

# %%
table.login = table.login.map(str.strip).str.lower()
table.company = table.company.map(str.strip)
table.location = table.location.map(str.strip)
table.avatar_url = table.avatar_url.map(str.strip)

# %%
corrections = pd.read_csv("contributors-corrections.csv")

# %%
table = table.merge(corrections, on="login", how="left")

# %%
table.company = table.corrected_company.fillna(table.company)

# %%
table.drop('corrected_company', axis=1, inplace=True)

# %%
table[table.company == ''].sort_values("login")
# Out:
#                                   repo          login           name  \
# 67           django-calaccess-raw-data        annkiha
# 72           django-calaccess-raw-data          cecht
# 106          django-calaccess-raw-data         danmit
# 42           django-calaccess-raw-data     elainewong    Elaine Wong
# 109          django-calaccess-raw-data      jayelle-o
# 21           django-calaccess-raw-data      karkinosw
# 58           django-calaccess-raw-data    katbuchholz
# 59           django-calaccess-raw-data  lauragomezrod
# 113          django-calaccess-raw-data         lengsj
# 22           django-calaccess-raw-data          malon
# 115          django-calaccess-raw-data           mb10
# 119          django-calaccess-raw-data    mikereicher
# 61           django-calaccess-raw-data        mjlorda
# 121          django-calaccess-raw-data       mmhirsch
# 93           django-calaccess-raw-data     nicolewest
# 95           django-calaccess-raw-data      pumadegit
# 125          django-calaccess-raw-data     regirob831
# 143  django-calaccess-campaign-browser         rkiddy      Ray Kiddy
# 126          django-calaccess-raw-data        samlo78
# 127          django-calaccess-raw-data    soorinkimmm
# 5            django-calaccess-raw-data   tocateunvals  Luciana Godoy
# 17           django-calaccess-raw-data         yujiap
#
#                 email company       location bio  \
# 67
# 72
# 106
# 42                                   Toronto
# 109
# 21
# 58
# 59
# 113
# 22
# 115
# 119
# 61
# 121
# 93
# 95
# 125
# 143  ray@ganymede.org          Sunnyvale, CA
# 126
# 127
# 5                                  Argentina
# 17
#
#                                             avatar_url  contributions
# 67   https://avatars.githubusercontent.com/u/113393...              1
# 72   https://avatars.githubusercontent.com/u/112753...              1
# 106  https://avatars.githubusercontent.com/u/800801...              1
# 42   https://avatars.githubusercontent.com/u/838923...              2
# 109  https://avatars.githubusercontent.com/u/168088...              1
# 21   https://avatars.githubusercontent.com/u/140054...              5
# 58   https://avatars.githubusercontent.com/u/113408...              2
# 59   https://avatars.githubusercontent.com/u/178048...              2
# 113  https://avatars.githubusercontent.com/u/723122...              1
# 22   https://avatars.githubusercontent.com/u/702708...              5
# 115  https://avatars.githubusercontent.com/u/615794...              1
# 119  https://avatars.githubusercontent.com/u/177726...              1
# 61   https://avatars.githubusercontent.com/u/779325...              2
# 121  https://avatars.githubusercontent.com/u/171683...              1
# 93   https://avatars.githubusercontent.com/u/147913...              1
# 95   https://avatars.githubusercontent.com/u/643226...              1
# 125  https://avatars.githubusercontent.com/u/178037...              1
# 143  https://avatars.githubusercontent.com/u/691368...              3
# 126  https://avatars.githubusercontent.com/u/140041...              1
# 127  https://avatars.githubusercontent.com/u/168025...              1
# 5    https://avatars.githubusercontent.com/u/785444...             25
# 17   https://avatars.githubusercontent.com/u/712073...              7

# %%
table.head(25)
# Out:
#                          repo           login                name  \
# 0   django-calaccess-raw-data        palewire           Ben Welsh
# 1   django-calaccess-raw-data        gordonje        James Gordon
# 2   django-calaccess-raw-data      aboutaaron      Aaron Williams
# 3   django-calaccess-raw-data      armendariz  Agustin Armendariz
# 4   django-calaccess-raw-data       anabranch       Bill Chambers
# 5   django-calaccess-raw-data    tocateunvals       Luciana Godoy
# 6   django-calaccess-raw-data         charlex      Charley Bodkin
# 7   django-calaccess-raw-data        bcipolli       Ben Cipollini
# 8   django-calaccess-raw-data        mhkeller      Michael Keller
# 9   django-calaccess-raw-data    myersjustinc        Justin Myers
# 10  django-calaccess-raw-data   anthonyjpesce       Anthony Pesce
# 11  django-calaccess-raw-data      burtherman         Burt Herman
# 12  django-calaccess-raw-data   sourcedouglas   Douglas Arellanes
# 13  django-calaccess-raw-data           nbedi           Neil Bedi
# 14  django-calaccess-raw-data  danhillreports            Dan Hill
# 15  django-calaccess-raw-data       amandabee      Amanda Hickman
# 16  django-calaccess-raw-data           benlk           Ben Keith
# 17  django-calaccess-raw-data          yujiap
# 18  django-calaccess-raw-data       ryanpitts          Ryan Pitts
# 19  django-calaccess-raw-data             ewr     Eric Richardson
# 20  django-calaccess-raw-data      stevenrich         Steven Rich
# 21  django-calaccess-raw-data       karkinosw
# 22  django-calaccess-raw-data           malon
# 23  django-calaccess-raw-data        enactdev   Chris A. Williams
# 24  django-calaccess-raw-data     joegermuska        Joe Germuska
#
#                              email                             company  \
# 0              ben.welsh@gmail.com                   Los Angeles Times
# 1              gordon.je@gmail.com     California Civic Data Coalition
# 2   aaron.colby.williams@gmail.com                 The Washington Post
# 3                                                       New York Times
# 4                                                           Databricks
# 5
# 6                charley@bodkin.me                   Los Angeles Times
# 7                bcipolli@ucsd.edu                        UC San Diego
# 8                code@mhkeller.com                           Bloomberg
# 9           justin@justinmyers.net                The Associated Press
# 10         anthonyjpesce@gmail.com                   Los Angeles Times
# 11                                                       Hacks/Hackers
# 12                                                Sourcefabric, o.p.s.
# 13              neilbedi@gmail.com                     Tampa Bay Times
# 14                                           Austin American-Statesman
# 15        amanda@velociraptor.info                   @buzzfeed-openlab
# 16                   ben@benlk.com          Investigative News Network
# 17
# 18          ryan.a.pitts@gmail.com                     Census Reporter
# 19                        e@ewr.is    Southern California Public Radio
# 20        steven.rich@washpost.com                     Washington Post
# 21
# 22
# 23                                                   Enact Development
# 24                joe@germuska.com  Northwestern University Knight Lab
#
#              location                                                bio  \
# 0         Los Angeles  Editor, @datadesk. Organizer, @california-civi...
# 1        Columbia, MO
# 2    Washington, D.C.
# 3
# 4          California
# 5           Argentina
# 6     Los Angeles, CA
# 7       San Diego, CA
# 8        New York, NY
# 9             Chicago
# 10        Los Angeles
# 11      San Francisco
# 12
# 13
# 14
# 15  San Francisco, CA  Senior Fellow, BuzzFeed Open Lab for Journalis...
# 16
# 17
# 18     Spokane, Wash.
# 19        Atlanta, GA
# 20    Los Angeles, CA
# 21
# 22
# 23     Washington, DC
# 24        Chicago, IL
#
#                                            avatar_url  contributions
# 0    https://avatars.githubusercontent.com/u/9993?v=3           1054
# 1   https://avatars.githubusercontent.com/u/430454...            728
# 2   https://avatars.githubusercontent.com/u/856628...            144
# 3   https://avatars.githubusercontent.com/u/952608...             50
# 4   https://avatars.githubusercontent.com/u/164250...             45
# 5   https://avatars.githubusercontent.com/u/785444...             25
# 6   https://avatars.githubusercontent.com/u/154274...             23
# 7   https://avatars.githubusercontent.com/u/407245...             20
# 8   https://avatars.githubusercontent.com/u/498744...             19
# 9   https://avatars.githubusercontent.com/u/764865...             18
# 10  https://avatars.githubusercontent.com/u/479290...             11
# 11  https://avatars.githubusercontent.com/u/133105...             11
# 12  https://avatars.githubusercontent.com/u/189336...              9
# 13  https://avatars.githubusercontent.com/u/255338...              9
# 14  https://avatars.githubusercontent.com/u/108746...              9
# 15  https://avatars.githubusercontent.com/u/150791...              7
# 16  https://avatars.githubusercontent.com/u/175418...              7
# 17  https://avatars.githubusercontent.com/u/712073...              7
# 18  https://avatars.githubusercontent.com/u/56477?v=3              6
# 19  https://avatars.githubusercontent.com/u/204350...              5
# 20  https://avatars.githubusercontent.com/u/175044...              5
# 21  https://avatars.githubusercontent.com/u/140054...              5
# 22  https://avatars.githubusercontent.com/u/702708...              5
# 23  https://avatars.githubusercontent.com/u/505562...              4
# 24  https://avatars.githubusercontent.com/u/46313?v=3              4

# %% [markdown]
# ### Contribution rankings

# %%
table.groupby("repo", as_index=False).contributions.sum().sort_values("contributions", ascending=False)
# Out:
#                                          repo  contributions
# 8                   django-calaccess-raw-data           2391
# 0   california-civic-data-coalition.github.io            806
# 1           django-calaccess-campaign-browser            731
# 4          django-calaccess-downloads-website            718
# 6             django-calaccess-processed-data            288
# 9    django-calaccess-technical-documentation            229
# 10                       django-postgres-copy            101
# 11                 python-calaccess-notebooks             62
# 2                   django-calaccess-cookbook             30
# 3                     django-calaccess-docker             29
# 5           django-calaccess-lobbying-browser             23
# 7           django-calaccess-project-template              8

# %%
table.groupby('login', as_index=False).contributions.sum().sort_values("contributions", ascending=False).head(10)
# Out:
#              login  contributions
# 114       palewire           2932
# 50        gordonje           1329
# 0       aboutaaron            379
# 124    sahilchinoy            126
# 13      armendariz             69
# 7        anabranch             47
# 11   anthonyjpesce             40
# 21         caseymm             33
# 60        jjelosua             29
# 136   tocateunvals             25

# %%
table.groupby('company', as_index=False).contributions.sum().sort_values("contributions", ascending=False).head(10)
# Out:
#                             company  contributions
# 45                Los Angeles Times           3017
# 14  California Civic Data Coalition           1329
# 81              The Washington Post            382
# 83                      UC Berkeley            126
# 54                   New York Times             72
# 0                                               66
# 23                       Databricks             47
# 88                        Vox Media             33
# 50                              NPR             29
# 1                          ( ˘▽˘)っ♨             21

# %%
table.groupby('location', as_index=False).contributions.sum().sort_values("contributions", ascending=False).head(10)
# Out:
#             location  contributions
# 26       Los Angeles           2976
# 14      Columbia, MO           1329
# 51  Washington, D.C.            383
# 0                               200
# 5       Berkeley, CA            126
# 32      New York, NY             54
# 10        California             47
# 52    Washington, DC             36
# 27   Los Angeles, CA             34
# 12           Chicago             26

# %% [markdown]
# ## Unique contributors

# %%
table.groupby("repo", as_index=False).size().reset_index().sort_values(0, ascending=False)
# Out:
#                                          repo    0
# 8                   django-calaccess-raw-data  132
# 1           django-calaccess-campaign-browser   18
# 0   california-civic-data-coalition.github.io    7
# 4          django-calaccess-downloads-website    7
# 9    django-calaccess-technical-documentation    5
# 5           django-calaccess-lobbying-browser    3
# 6             django-calaccess-processed-data    3
# 10                       django-postgres-copy    3
# 11                 python-calaccess-notebooks    2
# 2                   django-calaccess-cookbook    1
# 3                     django-calaccess-docker    1
# 7           django-calaccess-project-template    1

# %%
unique_contributors = table.groupby(["login", "company", "location", "avatar_url"]).contributions.sum().reset_index()

# %%
unique_contributors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 5 columns):
# login            144 non-null object
# company          144 non-null object
# location         144 non-null object
# avatar_url       144 non-null object
# contributions    144 non-null int64
# dtypes: int64(1), object(4)
# memory usage: 5.7+ KB

# %%
unique_contributors.sort_values("login").head(25)
# Out:
#             login                                     company  \
# 0      aboutaaron                         The Washington Post
# 1     absolutevan  Arizona Center for Investigative Reporting
# 2         achavez                          @DallasMorningNews
# 3      acoreynews                            Arizona Republic
# 4       amandabee                           @buzzfeed-openlab
# 5           amzam                               Texas Tribune
# 6       anabecker                         Wall Street Journal
# 7       anabranch                                  Databricks
# 8     anniedaniel                               Texas Tribune
# 9         annkiha
# 10      anthonydb                               DocumentCloud
# 11  anthonyjpesce                           Los Angeles Times
# 12  aquintero4354                           Los Angeles Times
# 13     armendariz                              New York Times
# 14          ashwu                                Northwestern
# 15       bcipolli                                UC San Diego
# 16           bdin                                Northwestern
# 17          benlk                  Investigative News Network
# 18    brianmcgill                     The Wall Street Journal
# 19     burtherman                               Hacks/Hackers
# 20    carloslemos                            Globoesporte.com
# 21        caseymm                                   Vox Media
# 22        caseypt                                      Azavea
# 23          cecht
# 24     cephillips                         Stanford University
#
#                 location                                         avatar_url  \
# 0       Washington, D.C.  https://avatars.githubusercontent.com/u/856628...
# 1                         https://avatars.githubusercontent.com/u/165300...
# 2             Dallas, TX  https://avatars.githubusercontent.com/u/682828...
# 3          Las Vegas, NV  https://avatars.githubusercontent.com/u/562616...
# 4      San Francisco, CA  https://avatars.githubusercontent.com/u/150791...
# 5                         https://avatars.githubusercontent.com/u/579612...
# 6                         https://avatars.githubusercontent.com/u/265281...
# 7             California  https://avatars.githubusercontent.com/u/164250...
# 8             Austin, TX  https://avatars.githubusercontent.com/u/512549...
# 9                         https://avatars.githubusercontent.com/u/113393...
# 10         United States  https://avatars.githubusercontent.com/u/273891...
# 11           Los Angeles  https://avatars.githubusercontent.com/u/479290...
# 12                        https://avatars.githubusercontent.com/u/177308...
# 13                        https://avatars.githubusercontent.com/u/952608...
# 14          Evanston, IL  https://avatars.githubusercontent.com/u/721038...
# 15         San Diego, CA  https://avatars.githubusercontent.com/u/407245...
# 16                        https://avatars.githubusercontent.com/u/944032...
# 17                        https://avatars.githubusercontent.com/u/175418...
# 18  District of Columbia  https://avatars.githubusercontent.com/u/858281...
# 19         San Francisco  https://avatars.githubusercontent.com/u/133105...
# 20     São Paulo, Brazil  https://avatars.githubusercontent.com/u/158696...
# 21          New York, NY  https://avatars.githubusercontent.com/u/352698...
# 22      Philadelphia, PA  https://avatars.githubusercontent.com/u/104247...
# 23                        https://avatars.githubusercontent.com/u/112753...
# 24             Palo Alto  https://avatars.githubusercontent.com/u/547438...
#
#     contributions
# 0             379
# 1               1
# 2               1
# 3               1
# 4               7
# 5               2
# 6               1
# 7              47
# 8               1
# 9               1
# 10              1
# 11             40
# 12              1
# 13             69
# 14              1
# 15             20
# 16              2
# 17              7
# 18              1
# 19             11
# 20              2
# 21             33
# 22              3
# 23              1
# 24             10

# %%
unique_contributors.to_csv("./unique-contributors.csv")
