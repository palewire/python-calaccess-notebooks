# %% [markdown]
# # Contributions
#
# Extract campaign contributions linked to a committee

# %%
import os
import settings
import pandas as pd

# %% [markdown]
# ### Pull in all filings

# %%
filings = pd.read_csv(os.path.join(settings.data_dir, "filings.csv"))

# %%
filings.head()
# Out:
#    calaccess_committee_id                                     committee_name  \
# 0                 1340976  2012 AUTO INSURANCE DISCOUNT ACT, YES ON PROPO...
# 1                 1340976  2012 AUTO INSURANCE DISCOUNT ACT, YES ON PROPO...
# 2                 1340976  2012 AUTO INSURANCE DISCOUNT ACT, YES ON PROPO...
# 3                 1340976  2012 AUTO INSURANCE DISCOUNT ACT, YES ON PROPO...
# 4                 1340976  2012 AUTO INSURANCE DISCOUNT ACT, YES ON PROPO...
#
#    calaccess_filing_id  date_filed   from_date   thru_date  \
# 0              1622725  2012-04-30  2011-01-01  2011-09-30
# 1              1635951  2012-04-30  2011-10-01  2011-12-31
# 2              1657731  2012-06-08  2012-01-01  2012-03-31
# 3              1677945  2012-07-30  2012-04-01  2012-06-30
# 4              1694941  2013-01-15  2012-07-01  2012-09-30
#
#    total_contributions  total_expenditures_made
# 0            8227127.0                1083096.0
# 1              47751.0                1264650.0
# 2               1707.0                 236438.0
# 3              21497.0                 239163.0
# 4              31800.0                3875759.0

# %% [markdown]
# ### Pull in all contributions

# %%
monetary_sql_template = """
SELECT *
FROM calaccess_processed_form460scheduleaitem
WHERE filing_id IN ({})
"""

# %%
monetary_sql = monetary_sql_template.format(
    ",".join(map(str, list(filings.calaccess_filing_id)))
)

# %%
contribs = pd.read_sql_query(monetary_sql, settings.db_connection)

# %%
trimmed_contribs = contribs.rename(columns={
    'filing_id': 'calaccess_filing_id',
    'id': 'ccdc_contrib_id',
    'transaction_id': 'calaccess_contrib_id'
}).drop([
    'line_item',
    'date_received_thru',
    'transaction_type',
    'memo_reference_number',
    'cumulative_ytd_amount',
    'cumulative_election_amount',
], axis=1)

# %%
trimmed_contribs.head()
# Out:
#    ccdc_contrib_id date_received calaccess_contrib_id contributor_code  \
# 0        210652300    2000-02-08                 INC8              OTH
# 1        210652301    2000-02-08                INC10              OTH
# 2        210652302    2000-02-08                INC15              OTH
# 3        210652303    2000-02-08                INC16              OTH
# 4        210652304    2000-02-08                INC17              OTH
#
#   contributor_committee_id contributor_title  \
# 0
# 1
# 2
# 3
# 4
#
#                   contributor_lastname contributor_firstname  \
# 0  GARDEN HIGHWAY MUTUAL WATER COMPANY
# 1                          GROSS FARMS                  J.J.
# 2                    M & T CHICO RANCH
# 3         NATOMAS MUTUAL WATER COMPANY
# 4       OJI BROTHERS FARM INCORPORATED
#
#   contributor_name_suffix contributor_city         ...          \
# 0                                YUBA CITY         ...
# 1                                   GRIMES         ...
# 2                                    CHICO         ...
# 3                                RIO LINDA         ...
# 4                                YUBA CITY         ...
#
#   intermediary_firstname intermediary_name_suffix intermediary_city  \
# 0
# 1
# 2
# 3
# 4
#
#   intermediary_state intermediary_zip intermediary_employer  \
# 0
# 1
# 2
# 3
# 4
#
#   intermediary_occupation intermediary_is_self_employed   amount  \
# 0                                                 False   234.82
# 1                                                 False   126.80
# 2                                                 False   263.72
# 3                                                 False  2563.73
# 4                                                 False   100.47
#
#   calaccess_filing_id
# 0              605917
# 1              605917
# 2              605917
# 3              605917
# 4              605917
#
# [5 rows x 28 columns]

# %% [markdown]
# ### Merge them

# %%
merged = pd.merge(
    filings,
    trimmed_contribs,
    how="inner",
    on="calaccess_filing_id"
)

# %%
unwanted_columns = [
    'from_date',
    'thru_date',
    'total_contributions',
    'total_expenditures_made',
    'ccdc_contrib_id',
    'date_filed',
    'calaccess_contrib_id',
    'contributor_code',
    'contributor_committee_id',
    'contributor_title',
    'contributor_name_suffix',
    'intermediary_committee_id',
    'intermediary_title',
    'intermediary_lastname',
    'intermediary_firstname',
    'intermediary_name_suffix',
    'intermediary_city',
    'intermediary_state',
    'intermediary_zip',
    'intermediary_employer',
    'intermediary_occupation',
    'intermediary_is_self_employed'
]

# %%
trimmed_merged = merged.drop(unwanted_columns, axis=1)

# %%
trimmed_merged.head()
# Out:
#    calaccess_committee_id                                     committee_name  \
# 0                 1340976  2012 AUTO INSURANCE DISCOUNT ACT, YES ON PROPO...
# 1                 1340976  2012 AUTO INSURANCE DISCOUNT ACT, YES ON PROPO...
# 2                 1340976  2012 AUTO INSURANCE DISCOUNT ACT, YES ON PROPO...
# 3                 1340976  2012 AUTO INSURANCE DISCOUNT ACT, YES ON PROPO...
# 4                 1340976  2012 AUTO INSURANCE DISCOUNT ACT, YES ON PROPO...
#
#    calaccess_filing_id date_received              contributor_lastname  \
# 0              1622725    2011-08-26                            JOSEPH
# 1              1635951    2011-10-20  ABERNATHY INSURANCE AGENCY  INC.
# 2              1635951    2011-11-02                CALGARD ASSOCIATES
# 3              1635951    2011-12-05                          CISNEROS
# 4              1635951    2011-10-01                            CONREY
#
#   contributor_firstname contributor_city contributor_state contributor_zip  \
# 0                GEORGE      LOS ANGELES                CA           90010
# 1                                ARCADIA                CA           91006
# 2                              SAN DIMAS                CA           91773
# 3                CARLOS       WILMINGTON                CA           90744
# 4                 JERRY           TUSTIN                CA           92780
#
#           contributor_employer      contributor_occupation  \
# 0  MERCURY GENERAL CORPORATION                    CHAIRMAN
# 1
# 2
# 3   UNIAMERICA INSURANCE  INC.                BROKER-AGENT
# 4  SIATT INSURANCE CORPORATION  INSURANCE AGENCY PRINCIPAL
#
#   contributor_is_self_employed      amount
# 0                        False  8077126.97
# 1                        False    14000.00
# 2                        False    10000.00
# 3                        False      250.00
# 4                        False      225.00

# %%
trimmed_merged.to_csv(
    os.path.join(settings.data_dir, 'contributions.csv'),
    index=False
)

# %% [markdown]
# ### Filter down to 2016 contributions

# %%
recent_filings = pd.read_csv(os.path.join(settings.data_dir, "filings-2016.csv"))

# %%
recent_contribs = trimmed_merged[trimmed_merged.calaccess_filing_id.isin(recent_filings.calaccess_filing_id)]

# %%
recent_contribs.head(10)
# Out:
#       calaccess_committee_id                              committee_name  \
# 3829                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 3830                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 3831                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 3832                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 3833                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 3834                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 3835                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 3836                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 3837                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 3838                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
#
#       calaccess_filing_id date_received contributor_lastname  \
# 3829              2083796    2016-09-18              BERGMAN
# 3830              2083796    2016-09-18                KAHLE
# 3831              2083796    2016-07-15             MCDEVITT
# 3832              2083796    2016-08-10      WARREN-SAMARIPA
# 3833              2083796    2016-07-26      WARREN-SAMARIPA
# 3834              2083796    2016-07-26              VENTURO
# 3835              2083796    2016-07-29               HANNON
# 3836              2083796    2016-08-06              SCHERER
# 3837              2083796    2016-08-19               SEXTON
# 3838              2083796    2016-09-15                WOLFF
#
#      contributor_firstname contributor_city contributor_state contributor_zip  \
# 3829              GRETCHEN    SPRING VALLEY                CA           91978
# 3830                 MYRNA        SAN DIEGO                CA           92109
# 3831                   LEO        ESCONDIDO                CA           92025
# 3832             STEPHANIE        SAN DIEGO                CA           92116
# 3833             STEPHANIE        SAN DIEGO                CA           92116
# 3834                  JOHN        SAN DIEGO                CA           92110
# 3835                 SUSAN         CARLSBAD                CA           92008
# 3836                 WAYNE        SAN DIEGO                CA           92117
# 3837              MICHELLE        SAN DIEGO                CA           92109
# 3838              MICHELLE        SAN DIEGO                CA           92107
#
#                                    contributor_employer  \
# 3829                                         A NEW PATH
# 3830                           NATIONAL SCHOOL DISTRICT
# 3831                                      LIFE IONIZERS
# 3832                          STEPHANIE WARREN SAMARIPA
# 3833                          STEPHANIE WARREN SAMARIPA
# 3834                                                SMI
# 3835                                       SUSAN HANNON
# 3836                                      WAYNE SCHERER
# 3837  CENTER FOR THE STUDY OF CANNABIS AND SOCIAL PO...
# 3838                                     MICHELLE WOLFF
#
#      contributor_occupation contributor_is_self_employed  amount
# 3829     EXECUTIVE DIRECTOR                        False    84.0
# 3830                TEACHER                        False    35.0
# 3831    SEO/CONTENT MANAGER                        False   198.0
# 3832           ENTREPRENEUR                        False   -50.0
# 3833           ENTREPRENEUR                         True    50.0
# 3834               ENGINEER                        False   198.0
# 3835                  SALES                         True   100.0
# 3836                  OWNER                         True    30.0
# 3837             RESEARCHER                        False    84.0
# 3838               COMEDIAN                         True    84.0

# %%
recent_contribs.to_csv(
    os.path.join(settings.data_dir, 'contributions-2016.csv'),
    index=False
)
